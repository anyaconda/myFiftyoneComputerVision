# %%
import numpy as np
import tensorflow as tf
from datetime import datetime


levels = 4
length = 1000
scale = 1

matrices = np.logspace([1,1], [levels,levels], num=levels, dtype='int') * scale


def compute(device, shape):
    # choose device
    with tf.device(device.device_type):  
        
        #create a matrix of shape
        random_matrix = tf.random.uniform(shape=shape, maxval=1, seed=1)
        
        # start timer
        start_time = datetime.now()
        
        # perform some linear algebra on matrix
        product = tf.matmul(random_matrix, tf.transpose(random_matrix))
        
        #end timer
        elapsed_time = datetime.now() - start_time

    return elapsed_time


for device in tf.config.list_physical_devices():
    print('\nDevice: {}'.format(device.device_type))
    total_time = 0
    for shape in matrices:
        time = compute(device, shape)
        time = time.seconds + time.microseconds/1e6
        total_time += time
        print('Shape: {}'.format(shape))
        print('Time: {:.3f}\n'.format(time))
    print('Total elapsed time: {}\n\n'.format(total_time))
# Out:
# 2025-05-22 18:30:41.749447: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747938642.658665   16229 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747938642.919130   16229 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747938645.371950   16229 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747938645.371989   16229 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747938645.371992   16229 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747938645.371994   16229 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-22 18:30:45.640596: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1747938664.146979   16229 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14791 MB memory:  -> device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0001:00:00.0, compute capability: 7.0
# Shape: [10 10]
# Time: 0.187
#
# Shape: [100 100]
# Time: 0.005
#
# Shape: [1000 1000]
# Time: 0.023
#
# Shape: [10000 10000]
# Time: 4.289
#
# Total elapsed time: 4.503715
#
#
#
# Device: GPU
# Shape: [10 10]
# Time: 0.395
#
# Shape: [100 100]
# Time: 0.019
#
# Shape: [1000 1000]
# Time: 0.013
#
# Shape: [10000 10000]
# Time: 0.321
#
# Total elapsed time: 0.747209

# %%
#check if gpu is available
tf.test.is_gpu_available()
# Out:
# I0000 00:00:1747938669.864046   16229 gpu_device.cc:2019] Created device /device:GPU:0 with 14791 MB memory:  -> device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0001:00:00.0, compute capability: 7.0
# True

# %% [markdown]
# Ken, please help!
