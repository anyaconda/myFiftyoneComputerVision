# %%
#meta for myFiftyoneComputerVision 6/12/2025. On-Prem. POC AI Doc Vision. Part 1. Vis51 Data w/ Dimensionality Reduction
# refer to https://docs.voxel51.com/tutorials/dimension_reduction.html?highlight=umap
# code src: https://github.com/voxel51/fiftyone/blob/v1.4.0/docs/source/tutorials/dimension_reduction.ipynb


#infra: WLaptop + VSCode
#      env: default
#      confirmed Python 3.10.4
#      numpy 2.1.3, pandas 2.2.3, scikit-learn 1.6.1, matplotlib 3.10.0
#      pip 22.0.4, ipykernel 6.29.0, ipython 8.20.0
#fiftyone 1.4.0, fiftyone-brain 0.20.1, fiftyone_db 1.1.7
#umap-learn 0.5.7
#glob2 0.7


#input: 'aml_mlp_Images_from_PDFs' # => 'DOC-SAMPLE-INVOICES-250_Images' $draft
#       'DOC_DATA/df_doc_sample-invoices-250.parquet'
#output: 51vis


#history
#6/12/2025 CREATE 51dataset (250 COUNT) FIRST TIME - DRAFT
#      Create and persist 1st time, so next time can just load
#      2 models x 3 dim reductions = 6 51vis
#      Sample dataset: Mendeley Data, Samples of electronic invoices (from 999 reduced to 250 for speedier POC)
#$note: No metadata to add field(s) to a dataset - better with with gt_label and a primitive field 
#$note: Need modifications to run the code after 51dataset is created and don't want to overwrite good things


#$config  $error $fix $manual persist5329 $draft

# %%
import sys
#import time as time
from glob import glob
import os

import numpy as np
import pandas as pd
pd.set_option('display.max_colwidth', 150)

# %%
import fiftyone as fo
import fiftyone.brain as fob
import fiftyone.zoo as foz

# %%
#----- GlOBAL VARS -----

#data #$config
DATA_PATH = 'DOC_DATA'
IMAGES_PATH =  'aml_mlp_Images_from_PDFs' #'DOC-SAMPLE-INVOICES-250_Images' $draft
DATA_SAMPLES_IN = DATA_PATH + '/df_doc_sample-invoices-250.parquet' 

#dataset
DATASET_NAME = "doc-sample-invoices-250b" #$draft

# %% [markdown]
# # POC AI-DOC-VISION
# ## Visualizing Data with Dimensionality Reduction Techniques

# %% [markdown]
# Using 51 walkthrough, run dimensionality reduction techniques (PCA, t-SNE, UMAP) on shipping docs in FiftyOne!

# %% [markdown]
# It covers the following:
#
# - Why dimensionality reduction?
# - Strengths and weaknesses of different dimensionality reduction techniques
# - Running built-in dimensionality reduction techniques in FiftyOne

# %% [markdown]
# Embeddings — numeric vectors that represent features of your input data. In computer vision for instance, image embeddings are used in reverse image search applications. And in the context of large language models (LLMs), documents are chunked and embedded (with text embedding models) for retrieval augmented generation (RAG).
#
# Embeddings are incredibly powerful, but given their high dimensionality (with lengths typically between 384 and 4096), they can be hard for humans to interpret and inspect. This is where dimensionality reduction techniques come in handy!

# %% [markdown]
# Dimensionality reduction techniques are quantitative methods for representing information from a higher dimensional space in a lower dimensional space. By squeezing our embeddings into two or three dimensions, we can visualize them to get a more intuitive understanding of the “hidden” structure in our data.
#
# When we project high dimensional data into a low dimensional space, we implicitly make a trade-off between representational complexity and interpretability. To compress embeddings, dimensionality reduction techniques make assumptions about the underlying data, its distribution, and the relationships between variables.
#
# 3 popular dimensionality reduction techniques: PCA, t-SNE, and UMAP. We will give a brief overview of the strengths, weaknesses, and assumptions of each technique. And we will illustrate that both the model used to generate embeddings, and the dimensionality reduction technique play essential roles in shaping the visualization of your data.
#
# *$note: dimensionality reduction techniques often have hyperparameters, which can have non-negligible impacts on the results. Here, we use the default hyperparameters (modify as you see fit!)*

# %% [markdown]
# ## Setup

# %% [markdown]
# Using the FiftyOne library for data management and visualization
# - use [scikit-learn](https://scikit-learn.org/stable/) for PCA and t-SNE, and
# - [umap-learn](https://umap-learn.readthedocs.io/en/latest/#) for UMAP dimension reduction implementations:

# %%
#!pip install -U fiftyone scikit-learn umap-learn

# %% [markdown]
# ## 0. Load Data
# 250 samples invoices
#
# ### 0a. Load tidy sample with metadata
# previously created in `0_data` step

# %%
df_samples = pd.read_parquet(DATA_SAMPLES_IN) #$draft
print(df_samples.shape)
print(df_samples.info())
df_samples.head()
# Out:
# (250, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   image_file_path       250 non-null    object
#  1   image_file_name       250 non-null    object
#  2   embeddings_resnet101  250 non-null    object
#  3   embeddings_clip       250 non-null    object
# dtypes: object(4)
# memory usage: 7.9+ KB
# None
#                                    image_file_path         image_file_name  \
# 0    aml_mlp_Images_from_PDFs/invoice_0_PAGE_0.jpg    invoice_0_PAGE_0.jpg
# 1  aml_mlp_Images_from_PDFs/invoice_100_PAGE_0.jpg  invoice_100_PAGE_0.jpg
# 2  aml_mlp_Images_from_PDFs/invoice_101_PAGE_0.jpg  invoice_101_PAGE_0.jpg
# 3  aml_mlp_Images_from_PDFs/invoice_102_PAGE_0.jpg  invoice_102_PAGE_0.jpg
# 4  aml_mlp_Images_from_PDFs/invoice_103_PAGE_0.jpg  invoice_103_PAGE_0.jpg
#
#                                                                                                                                     embeddings_resnet101  \
# 0  [8.924403664423153e-05, 0.0048162308521568775, 0.03182847797870636, 5.193899050937034e-05, 0.0, 0.00242895120754838, 0.0007508651469834149, 0.0007...
# 1  [8.924376015784219e-05, 0.004187495913356543, 0.03474236652255058, 7.997202192200348e-05, 0.0, 0.0032261619344353676, 0.0011029231827706099, 0.000...
# 2  [8.924378198571503e-05, 0.0044737826101481915, 0.030559316277503967, 5.1939110562670976e-05, 0.0, 0.0018650214187800884, 0.0006811099592596292, 0....
# 3  [8.924362919060513e-05, 0.004991775378584862, 0.03338786959648132, 5.19387649546843e-05, 0.0, 0.003409937024116516, 0.0006417044205591083, 0.00087...
# 4  [8.924397843657061e-05, 0.0063186888583004475, 0.03089168108999729, 5.193864490138367e-05, 0.0, 0.0036326711997389793, 0.00038263987516984344, 0.0...
#
#                                                                                                                                          embeddings_clip
# 0  [0.7366375923156738, -0.3562765121459961, 0.36882540583610535, 0.04245000332593918, 0.07245597243309021, 0.03032068908214569, 0.3071814477443695, ...
# 1  [0.659477174282074, -0.22650748491287231, 0.2817688584327698, 0.01946428418159485, 0.18970462679862976, -0.022963613271713257, 0.38750407099723816...
# 2  [0.6147462129592896, -0.05863085389137268, 0.3097462058067322, 0.23508228361606598, 0.20303219556808472, -0.14483943581581116, 0.15972954034805298...
# 3  [0.6534630060195923, -0.21887809038162231, 0.25023651123046875, -0.014195457100868225, 0.2514387369155884, -0.04046304523944855, 0.349435985088348...
# 4  [0.5377695560455322, 0.10842184722423553, 0.1856258511543274, 0.2833606004714966, 0.21918542683124542, -0.23293058574199677, 0.18361154198646545, ...

# %% [markdown]
# ## 1. Create 51 Dataset
# Load sample images, include a gt_label + field(s)

# %%
# DATASET_NAME = "NAME TO DELETE" 

# #RUN ONLY IF WANT TO DELETE A DATASET
# #Snippet: Recreate dataset every time
# if DATASET_NAME in fo.list_datasets():
#     # Load your FiftyOne dataset
#     ds_docs = fo.load_dataset(DATASET_NAME)
#     ds_docs.delete() #$config
# else:
#     print("Create dataset")

# print(fo.list_datasets())
# Out:
# ['clustering-demo', 'clustering-demo2', 'doc-images', 'doc-images-2359', 'doc-sample-invoices-250b']

# %%
# #Snippet: Load the dataset from disc
# try:
#     # Load your FiftyOne dataset
#     dataset = fo.load_dataset(DATASET_NAME) #class 'fiftyone.core.dataset.Dataset'
# except ValueError:
# # If the dataset doesn't exist, create it from a directory of images
#     dataset = fo.Dataset.from_dir(DATA_PATH, dataset_type=fo.types.FiftyOneDataset, name=DATASET_NAME) #class 'fiftyone.core.dataset.Dataset'
#     dataset = fo.load_dataset(DATASET_NAME)
 
# print(fo.list_datasets())

# %%
# step: Load dataset 1st time - 250 docs
try:
    # Load your FiftyOne dataset
    dataset = fo.load_dataset(DATASET_NAME) #class 'fiftyone.core.dataset.Dataset'
except ValueError:
    # If the dataset doesn't exist, create it from a dir of images
    dataset = fo.Dataset.from_images_dir(IMAGES_PATH, name=DATASET_NAME) #class 'fiftyone.core.dataset.Dataset'
 
print(fo.list_datasets())
# Out:
#  100% |█████████████████| 250/250 [44.4ms elapsed, 0s remaining, 5.6K samples/s]
# ['clustering-demo', 'clustering-demo2', 'doc-images', 'doc-images-2359', 'doc-sample-invoices-250', 'doc-sample-invoices-250a', 'doc-sample-invoices-250b']

# %%
# step: Load the full dataset 1st time
#list all images in dir of images
all_images = glob(IMAGES_PATH+"/*.jpg")
print(len(all_images))

all_images
# Out:
# 250
# ['aml_mlp_Images_from_PDFs\\invoice_0_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_100_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_101_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_102_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_103_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_104_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_105_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_106_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_107_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_108_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_109_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_10_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_110_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_111_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_112_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_113_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_114_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_115_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_116_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_117_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_118_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_119_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_11_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_120_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_121_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_122_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_123_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_124_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_125_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_126_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_127_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_128_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_129_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_12_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_130_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_131_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_132_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_133_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_134_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_135_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_136_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_137_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_138_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_139_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_13_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_140_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_141_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_142_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_143_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_144_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_145_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_146_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_147_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_148_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_149_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_14_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_150_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_151_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_152_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_153_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_154_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_155_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_156_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_157_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_158_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_159_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_15_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_160_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_161_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_162_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_163_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_164_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_165_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_166_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_167_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_168_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_169_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_16_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_170_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_171_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_172_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_173_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_174_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_175_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_176_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_177_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_178_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_179_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_17_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_180_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_181_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_182_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_183_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_184_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_185_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_186_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_187_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_188_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_189_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_18_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_190_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_191_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_192_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_193_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_194_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_195_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_196_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_197_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_198_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_199_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_19_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_1_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_200_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_201_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_202_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_203_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_204_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_205_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_206_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_207_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_208_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_209_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_20_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_210_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_211_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_212_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_213_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_214_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_215_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_216_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_217_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_218_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_219_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_21_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_220_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_221_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_222_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_223_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_224_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_225_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_226_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_227_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_228_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_229_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_22_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_230_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_231_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_232_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_233_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_234_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_235_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_236_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_237_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_238_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_239_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_23_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_240_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_241_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_242_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_243_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_244_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_245_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_246_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_247_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_248_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_249_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_24_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_250_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_251_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_252_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_253_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_254_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_255_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_256_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_257_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_258_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_259_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_25_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_260_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_261_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_262_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_263_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_264_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_265_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_266_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_267_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_268_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_269_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_26_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_270_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_271_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_272_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_273_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_274_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_275_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_276_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_277_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_278_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_279_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_27_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_280_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_281_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_282_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_283_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_284_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_285_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_286_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_287_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_288_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_289_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_28_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_290_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_291_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_292_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_293_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_294_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_295_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_296_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_297_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_298_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_299_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_29_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_2_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_300_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_301_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_302_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_303_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_304_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_305_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_306_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_307_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_308_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_309_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_30_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_310_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_311_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_312_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_313_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_314_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_315_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_316_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_317_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_318_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_319_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_31_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_320_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_321_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_322_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_32_PAGE_0.jpg',
#  'aml_mlp_Images_from_PDFs\\invoice_3_PAGE_0.jpg']

# %% [markdown]
# howto: Adding fields to a dataset
# refer to https://docs.voxel51.com/user_guide/using_datasets.html#adding-fields-to-a-sample
# https://docs.voxel51.com/user_guide/using_datasets.html#adding-fields-to-a-dataset

# %%
# # step: Load the full dataset 1st time $config - only if have ground truth and a primitive field
# #add gt_label and a field to FiftyOne dataset
# i=0
# for image in all_images:
#     #print(image)
#     sample = fo.Sample(
#         filepath=image,
#         ground_truth = fo.Classification(label=df_samples.iloc[i]['DOCUMENT_TYPE_NAME']))
#     dataset.add_sample(sample)
#     sample["carrier"] = df_samples.iloc[i]['CARRIER']
#     sample.save()

#     i += 1

# #ensure right media type
# dataset.media_type

# %%
dataset
# Out:
# Name:        doc-sample-invoices-250b
# Media type:  image
# Num samples: 250
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:               fiftyone.core.fields.ObjectIdField
#     filepath:         fiftyone.core.fields.StringField
#     tags:             fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:         fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     created_at:       fiftyone.core.fields.DateTimeField
#     last_modified_at: fiftyone.core.fields.DateTimeField

# %%
dataset.stats(include_media=True)
# Out:
# Computing metadata...
#  100% |█████████████████| 250/250 [198.5ms elapsed, 0s remaining, 1.3K samples/s]
# {'samples_count': 250,
#  'samples_bytes': 64219,
#  'samples_size': '62.7KB',
#  'media_bytes': 50294973,
#  'media_size': '48.0MB',
#  'total_bytes': 50359192,
#  'total_size': '48.0MB'}

# %%
# #preview
# dataset.count_values("ground_truth.label")

# %%
# #preview
# dataset.count_values("carrier")

# %%
#Launch if want to view 51dataset, images only
#session = fo.launch_app([ds_name])

# %% [markdown]
# ### 1.1 Dimensionality reduction techniques
# Compare and contrast our 3 dimensionality reduction techniques with two image embedding models: [ResNet-101](https://pytorch.org/vision/main/models/generated/torchvision.models.resnet101.html) and [CLIP](https://github.com/openai/CLIP). Whereas ResNet-101 is a more traditional vision model, representing the relationships between pixels and patches in images, CLIP captures more of the semantic content of the images.

# %% [markdown]
# We can load both from the [FiftyOne Model Zoo](https://docs.voxel51.com/user_guide/model_zoo/index.html):

# %%
clip = foz.load_zoo_model("clip-vit-base32-torch")
resnet101 = foz.load_zoo_model("resnet101-imagenet-torch")

# %% [markdown]
# Then generating embeddings for each model amounts to making a single call to the dataset’s `compute_embeddings()` method:

# %%
## compute and store resnet101 embeddings $note: time consuming
dataset.compute_embeddings(
    resnet101, 
    embeddings_field="resnet101_embeddings"
)

## compute and store clip embeddings 
dataset.compute_embeddings(
    clip, 
    embeddings_field="clip_embeddings"
)
# Out:
#  100% |█████████████████| 250/250 [11.8m elapsed, 0s remaining, 0.3 samples/s]
#  100% |█████████████████| 250/250 [16.8s elapsed, 0s remaining, 15.6 samples/s]

# %% [markdown]
# ### Tutorial: Dimensionality Reduction API in FiftyOne

# %% [markdown]
# Recap the API for running dimensionality reduction in FiftyOne.
# The [FiftyOne Brain](https://docs.voxel51.com/user_guide/brain.html) provides a [compute_visualization()](https://docs.voxel51.com/api/fiftyone.brain.html#fiftyone.brain.compute_visualization) function that can be used to run dimensionality reduction on your data.

# %% [markdown]
# The first and only positional argument to this function is a sample collection, which can be either a [Dataset](https://docs.voxel51.com/user_guide/using_datasets.html#datasets) or a [DatasetView](https://docs.voxel51.com/user_guide/using_views.html).

# %% [markdown]
# Beyond that, you need to specify the following three things:
# 1. *What* you want to reduce the dimensionality of.
# 2. *How* you want to reduce the dimensionality.
# 3. *Where* you want to store the results.

# %% [markdown]
# ### Tutorial 1. What to reduce the dimensionality of

# %% [markdown]
# There are multiple ways to specify what you would like dimension-reduced. Here are a few options:
#
# - You can specify the name of the field containing the embeddings you would like to reduce using the `embeddings` argument. If your embeddings are stored in field "my_embeddings_field" on your samples, you would employ the syntax `embeddings="my_embeddings_field"`. This is useful if you need to reuse the same embeddings for multiple dimensionality reduction techniques, or for other brain methods.
# - You can pass the embeddings in directly using as numpy array, also via the `embeddings` argument. This is useful if you have already computed your embeddings, and don’t need to store them on your samples.
# - You can specify the *model* you would like to use to generate embeddings. This can be:
#     - A `FiftyOne.Model` instance
#     - The name (a string) of a model from the model zoo, in which case the model by that will be loaded from the FiftyOne Model Zoo.
#     - A Hugging Face Transformers model, in which case the model will be converted to a `FiftyOne.Model` instance. See the [Hugging Face integration docs](https://docs.voxel51.com/integrations/huggingface.html) for more details.

# %% [markdown]
# ### Tutorial 2. How to reduce the dimensionality

# %% [markdown]
# You can specify the base dimensionality reduction technique to use via the `method` argument. This can be one of the following strings: `pca`, `tsne`, `umap`, or `manual`.
#
# For `pca`, `tsne`, and `umap`, you can specify the number of dimensions to reduce to via the `num_dims` argument. Additionally, you can specify hyperparameters for each technique as kwargs. For a complete description of available options, check out the visualization configs:
# [TSNEVisualizationConfig](https://docs.voxel51.com/api/fiftyone.brain.visualization.html#fiftyone.brain.visualization.TSNEVisualizationConfig),
# [UMAPVisualizationConfig](https://docs.voxel51.com/api/fiftyone.brain.visualization.html#fiftyone.brain.visualization.UMAPVisualizationConfig), and [PCAVisualizationConfig](https://docs.voxel51.com/api/fiftyone.brain.visualization.html#fiftyone.brain.visualization.PCAVisualizationConfig).
#
# You can use `method="manual"` if you already have the dimensionality-reduced data, and just want to store it on your samples for visualization purposes.

# %% [markdown]
# ### Tutorial 3. Where to store the results

# %% [markdown]
# This is done via the `brain_key` argument. Once you have run the `compute_visualization()` method, you will be able to select this brain key in the FiftyOne App to visualize the results. You can also use the brain key to access the results programmatically:

# %%
# #Snippet: 
# import fiftyone as fo
# import fiftyone.brain as fob
# import fiftyone.zoo as foz

# #dataset = foz.load_zoo_dataset("cifar10", split="test")

# ## Compute PCA visualization
# fob.compute_visualization(
#     dataset,
#     embeddings="resnet101",
#     method="pca",
#     brain_key="resnet101_pca"
# )

# ## Access results
# pca_resnet_results = dataset_docs.load_brain_results("pca_resnet101")

# %% [markdown]
# #### 1.1a Dimensionality Reduction with PCA

# %% [markdown]
# [Principal Component Analysis](https://en.wikipedia.org/wiki/Principal_component_analysis), or PCA, is a dimensionality reduction technique that seeks to preserve as much variance as possible. Intuitively, PCA finds a set of orthogonal axes (principal components) that jointly “explain” as much of the variation in the data as possible. Mathematically, you can interpret PCA algorithms as effectively performing singular value decompositions and truncating the number of dimensions by eliminating the singular vectors with the smallest eigenvalues.

# %% [markdown]
# **Strengths**
#
# - Simple, intuitive, and efficient for large datasets!
# - PCA is amenable to new data: If you have precomputed the transformation on an initial set of embeddings, you can apply that transformation to new embeddings and immediately visualize them in the same space.
#
# **Limitations**
#
# - Assumes that the relationships between variables are linear — an assumption which often does not hold when the inputs are embeddings, which themselves come from highly nonlinear deep neural networks
# - Very susceptible to outliers.

# %% [markdown]
# #### 1.1a Running PCA on Embeddings

# %% [markdown]
# PCA is natively supported by the FiftyOne Brain’s `compute_visualization()`. To reduce dimensionality for a set of embeddings, we can specify the field the embeddings are stored in, and pass in `method="pca"`. In the app, we can open up an Embeddings panel to view the results:

# %%
## PCA with ResNet101 embeddings
fob.compute_visualization(
    dataset, 
    embeddings="resnet101_embeddings", 
    method="pca", 
    brain_key="resnet101_pca"
)

## PCA with CLIP embeddings
fob.compute_visualization(
    dataset, 
    embeddings="clip_embeddings", 
    method="pca", 
    brain_key="clip_pca"
)
# Out:
# Generating visualization...
# Generating visualization...

# %%
## Access results
pca_resnet_results = dataset.load_brain_results("resnet101_pca")

# %% [markdown]
# ### Tutorial: Vis

# %% [markdown]
# We can color by any attribute on our samples — in this case the ground truth label — and filter the contents of the sample grid interactively by selecting regions in the embeddings panel.

# %% [markdown]
# View and interpret both the CLIP and ResNet-101 embeddings:
# i.e.
# - the PCA plot does seem to very loosely retain information from the embeddings (and the original images). However, when we color by label, there is substantial overlap from one class to another.
# - Restricting the CLIP PCA view to just automobiles, trucks, and ships, we can see that the distributions for all three classes are essentially identical, aside from the ships extending slightly farther out.

# %% [markdown]
# #### 1.1b Dimensionality Reduction with t-SNE

# %% [markdown]
# [t-Distributed Stochastic Neighbor Embedding](https://en.wikipedia.org/wiki/T-distributed_stochastic_neighbor_embedding), or t-SNE, is a nonlinear dimensionality reduction technique that aims to, roughly speaking, keep neighbors close. More precisely, t-SNE takes the initial, high-dimensional data (in our case embedding vectors) and computes the similarity between inputs. The algorithm then attempts to learn a lower-dimensional representation which preserves as much of the similarity as possible. Mathematically, this learning is achieved by minimizing the [Kullback-Leibler divergence](https://en.wikipedia.org/wiki/Kullback%E2%80%93Leibler_divergence) between the high-dimensional (fixed) and low-dimensional (trained) distributions.

# %% [markdown]
# **Strengths**
#
# - t-SNE is nonlinear, making it a much better fit for (embeddings computed on) datasets like MNIST and CIFAR-10.
# - The technique is good at preserving local structure, making it easy to see clustering in data!
#
# **Limitations**
#
# - t-SNE relies on random initialization, so good fits are not guaranteed
# Still sensitive to outliers
# - Not scalable: for a dataset with n samples, t-SNE takes $\mathcal{O}(n^2)$ time to run, and requires $\mathcal{O}(n^2)$ space to operate

# %% [markdown]
# #### 1.1b Running t-SNE on Embeddings

# %% [markdown]
# t-SNE is natively supported by the FiftyOne Brain’s `compute_visualization()`, so we can run dimensionality reduction on our embeddings by passing `method="tsne"`:

# %%
#$error ValueError: n_components=50 must be between 1 and min(n_samples, n_features)=21 with svd_solver='randomized'

## t-SNE with ResNet101 embeddings
fob.compute_visualization(
    dataset, 
    embeddings="resnet101_embeddings", 
    method="tsne", 
    brain_key="resnet101_tsne"
)

## t-SNE with CLIP embeddings
fob.compute_visualization(
    dataset, 
    embeddings="clip_embeddings", 
    method="tsne", 
    brain_key="clip_tsne"
)
# Out:
# Generating visualization...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 250 samples in 0.000s...
# c:\Users\chq-anyac\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# [t-SNE] Computed neighbors for 250 samples in 0.722s...
# [t-SNE] Computed conditional probabilities for sample 250 / 250
# [t-SNE] Mean sigma: 0.251550
# [t-SNE] Computed conditional probabilities in 0.007s
# [t-SNE] Iteration 50: error = 52.1544037, gradient norm = 0.2913886 (50 iterations in 0.019s)
# [t-SNE] Iteration 100: error = 51.8915939, gradient norm = 0.2656487 (50 iterations in 0.018s)
# [t-SNE] Iteration 150: error = 50.2727547, gradient norm = 0.3080124 (50 iterations in 0.018s)
# [t-SNE] Iteration 200: error = 49.9839478, gradient norm = 0.2990556 (50 iterations in 0.018s)
# [t-SNE] Iteration 250: error = 49.3990593, gradient norm = 0.2793668 (50 iterations in 0.018s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.399059
# [t-SNE] Iteration 300: error = 0.1312840, gradient norm = 0.0012488 (50 iterations in 0.018s)
# [t-SNE] Iteration 350: error = 0.1246547, gradient norm = 0.0008193 (50 iterations in 0.018s)
# [t-SNE] Iteration 400: error = 0.1218516, gradient norm = 0.0011718 (50 iterations in 0.017s)
# [t-SNE] Iteration 450: error = 0.1207276, gradient norm = 0.0004332 (50 iterations in 0.023s)
# [t-SNE] Iteration 500: error = 0.1200792, gradient norm = 0.0004234 (50 iterations in 0.018s)
# [t-SNE] Iteration 550: error = 0.1193081, gradient norm = 0.0003748 (50 iterations in 0.018s)
# [t-SNE] Iteration 600: error = 0.1187897, gradient norm = 0.0002550 (50 iterations in 0.019s)
# [t-SNE] Iteration 650: error = 0.1188961, gradient norm = 0.0003202 (50 iterations in 0.018s)
# [t-SNE] Iteration 700: error = 0.1186252, gradient norm = 0.0003167 (50 iterations in 0.017s)
# [t-SNE] Iteration 750: error = 0.1183935, gradient norm = 0.0003212 (50 iterations in 0.011s)
# [t-SNE] Iteration 800: error = 0.1184789, gradient norm = 0.0003683 (50 iterations in 0.014s)
# [t-SNE] Iteration 850: error = 0.1179036, gradient norm = 0.0002491 (50 iterations in 0.017s)
# [t-SNE] Iteration 900: error = 0.1176812, gradient norm = 0.0005432 (50 iterations in 0.019s)
# [t-SNE] Iteration 950: error = 0.1175442, gradient norm = 0.0003684 (50 iterations in 0.029s)
# [t-SNE] Iteration 1000: error = 0.1171826, gradient norm = 0.0002673 (50 iterations in 0.018s)
# [t-SNE] KL divergence after 1000 iterations: 0.117183
# Generating visualization...
# c:\Users\chq-anyac\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 250 samples in 0.000s...
# [t-SNE] Computed neighbors for 250 samples in 0.007s...
# [t-SNE] Computed conditional probabilities for sample 250 / 250
# [t-SNE] Mean sigma: 0.651822
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 58.9685669, gradient norm = 0.2787340 (50 iterations in 0.014s)
# [t-SNE] Iteration 100: error = 58.0616302, gradient norm = 0.3188216 (50 iterations in 0.018s)
# [t-SNE] Iteration 150: error = 58.3833008, gradient norm = 0.2610556 (50 iterations in 0.018s)
# [t-SNE] Iteration 200: error = 55.7792130, gradient norm = 0.3154004 (50 iterations in 0.021s)
# [t-SNE] Iteration 250: error = 58.9934425, gradient norm = 0.2700813 (50 iterations in 0.019s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 58.993443
# [t-SNE] Iteration 300: error = 0.4704224, gradient norm = 0.0033756 (50 iterations in 0.016s)
# [t-SNE] Iteration 350: error = 0.4410209, gradient norm = 0.0009009 (50 iterations in 0.015s)
# [t-SNE] Iteration 400: error = 0.4379732, gradient norm = 0.0005749 (50 iterations in 0.016s)
# [t-SNE] Iteration 450: error = 0.4365046, gradient norm = 0.0005432 (50 iterations in 0.012s)
# [t-SNE] Iteration 500: error = 0.4361882, gradient norm = 0.0004223 (50 iterations in 0.011s)
# [t-SNE] Iteration 550: error = 0.4356815, gradient norm = 0.0002817 (50 iterations in 0.014s)
# [t-SNE] Iteration 600: error = 0.4357274, gradient norm = 0.0003605 (50 iterations in 0.017s)
# [t-SNE] Iteration 650: error = 0.4356700, gradient norm = 0.0002239 (50 iterations in 0.012s)
# [t-SNE] Iteration 700: error = 0.4354841, gradient norm = 0.0002563 (50 iterations in 0.013s)
# [t-SNE] Iteration 750: error = 0.4352241, gradient norm = 0.0001150 (50 iterations in 0.013s)
# [t-SNE] Iteration 800: error = 0.4353944, gradient norm = 0.0001239 (50 iterations in 0.017s)
# [t-SNE] Iteration 850: error = 0.4354487, gradient norm = 0.0001181 (50 iterations in 0.018s)
# [t-SNE] Iteration 900: error = 0.4354571, gradient norm = 0.0001248 (50 iterations in 0.019s)
# [t-SNE] Iteration 950: error = 0.4357182, gradient norm = 0.0001135 (50 iterations in 0.019s)
# [t-SNE] Iteration 1000: error = 0.4355828, gradient norm = 0.0002022 (50 iterations in 0.019s)
# [t-SNE] KL divergence after 1000 iterations: 0.435583

# %% [markdown]
# View and interpret both the CLIP and ResNet-101 embeddings:
# i.e.
# - Looking at the results of t-SNE dimensionality reduction on both ResNet-101 and CLIP embeddings, we can see a lot more separation between the distributions of different classes.
# - In both cases, similar classes are still close to each other — for instance, automobiles and trucks are adjacent — but we can also mostly distinguish a main cluster for almost every class. In other words, t-SNE does a very good job at capturing local structure, and a decent job at capturing global structure.

# %% [markdown]
# #### 1.1c Dimensionality Reduction with UMAP

# %% [markdown]
# [Uniform Manifold Approximation and Projection](https://umap-learn.readthedocs.io/en/latest/) (UMAP) is a nonlinear dimensionality reduction technique based on the mathematics of [topology](https://en.wikipedia.org/wiki/Topology). No gory details, as there is an excellent visual explanation of the approach [here](https://umap-learn.readthedocs.io/en/latest/how_umap_works.html), but in essence, UMAP treats the input data as points lying on a special kind of surface called a manifold (technically here a [Riemannian manifold](https://en.wikipedia.org/wiki/Riemannian_manifold)), and tries to learn a lower dimensional representation of the manifold. This explicitly takes global structure into consideration, as opposed to t-SNE, which concerns itself with keeping neighbors close (local structure).

# %% [markdown]
# **Strengths**
#
# - Preserves both global and local structure
# - Better scaling than t-SNE with dataset size
#
# **Limitations**
#
# - Like t-SNE, UMAP relies on randomness, and is dependent upon hyperparameters
# - UMAP assumes that the manifold is locally connected. This can cause problems if there are a few data points that are very far away from the rest of the data.

# %% [markdown]
# #### 1.1c Running UMAP on Embeddings

# %% [markdown]
# UMAP  is natively supported by the FiftyOne Brain’s `compute_visualization()`, so we can run dimensionality reduction on our embeddings by passing `method="umap"`:

# %%
## UMAP with ResNet101 embeddings
fob.compute_visualization(
    dataset, 
    embeddings="resnet101_embeddings", 
    method="umap", 
    brain_key="resnet101_umap"
)

## UMAP with CLIP embeddings
fob.compute_visualization(
    dataset, 
    embeddings="clip_embeddings", 
    method="umap", 
    brain_key="clip_umap"
)
# Out:
# Generating visualization...
# c:\Users\chq-anyac\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# UMAP( verbose=True)
# Mon Jun  2 13:05:48 2025 Construct fuzzy simplicial set
# Mon Jun  2 13:05:48 2025 Finding Nearest Neighbors
# Mon Jun  2 13:05:53 2025 Finished Nearest Neighbor Search
# Mon Jun  2 13:05:55 2025 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Mon Jun  2 13:05:57 2025 Finished embedding
# Generating visualization...
# UMAP( verbose=True)
# Mon Jun  2 13:05:57 2025 Construct fuzzy simplicial set
# Mon Jun  2 13:05:57 2025 Finding Nearest Neighbors
# Mon Jun  2 13:05:57 2025 Finished Nearest Neighbor Search
# Mon Jun  2 13:05:57 2025 Construct embedding
# c:\Users\chq-anyac\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Epochs completed:   0%|            0/500 [00:00]
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Mon Jun  2 13:05:57 2025 Finished embedding

# %% [markdown]
# View and interpret both the CLIP and ResNet-101 embeddings:
# i.e.
# - For both sets of embeddings, the clusters are a lot more spread out than with t-SNE. For ResNet-101, all of the vehicles (automobile, truck, airplane, ship) are in one mega-cluster — or two smaller clusters, depending on how you view it — and all of the animals are in another mega-cluster.
# - Interestingly, for the CLIP embeddings, we see that the `airplane` cluster is situated close to both `bird` and `ship`. The `car` and `truck` clusters are very close together; and the `cat` and `dog` clusters are very close together.

# %%
#persist 51dataset $manual #$draft
dataset.export(export_dir='persist5329', dataset_type=fo.types.FiftyOneDataset)
# Out:
# Directory 'persist5329' already exists; export will be merged with existing files
# Exporting samples...
#  100% |████████████████████| 250/250 [830.7ms elapsed, 0s remaining, 300.9 docs/s]

# %%
#Load persisted 51dataset from disc
loaded_dataset2 = fo.Dataset.from_dir('persist5329', dataset_type=fo.types.FiftyOneDataset, name='doc-images2') #$draft
loaded_dataset2.__class__
# Out:
# Importing samples...
#  100% |█████████████████| 250/250 [14.7ms elapsed, 0s remaining, 17.1K samples/s]
# fiftyone.core.dataset.Dataset

# %%
fo.list_datasets()
# Out:
# ['clustering-demo',
#  'clustering-demo2',
#  'doc-images',
#  'doc-images-2359',
#  'doc-images2',
#  'doc-sample-invoices-250',
#  'doc-sample-invoices-250a',
#  'doc-sample-invoices-250b']

# %%
loaded_dataset2
# Out:
# Name:        doc-images2
# Media type:  image
# Num samples: 250
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:                   fiftyone.core.fields.ObjectIdField
#     filepath:             fiftyone.core.fields.StringField
#     tags:                 fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:             fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     created_at:           fiftyone.core.fields.DateTimeField
#     last_modified_at:     fiftyone.core.fields.DateTimeField
#     resnet101_embeddings: fiftyone.core.fields.VectorField
#     clip_embeddings:      fiftyone.core.fields.VectorField

# %%
#launch if needed here
session = fo.launch_app(loaded_dataset2)
# Out:
# Could not connect session, trying again in 10 seconds
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[28], line 2
#       1 #launch if needed here
# ----> 2 session = fo.launch_app(loaded_dataset2)
#
# File c:\Users\chq-anyac\AppData\Local\Programs\Python\Python310\lib\site-packages\fiftyone\core\session\session.py:192, in launch_app(dataset, view, sample_id, group_id, spaces, color_scheme, plots, port, address, remote, browser, height, auto, config)
#     149 """Launches the FiftyOne App.
#     150
#     151 Note that only one App instance can be opened at a time. If this method is
#    (...)
#     189     a :class:`Session`
#     190 """
#     191 global _session  # pylint: disable=global-statement
# --> 192 _session = Session(
#     193     dataset=dataset,
#     194     view=view,
#     195     sample_id=sample_id,
#     196     group_id=group_id,
#     197     spaces=spaces,
#     198     color_scheme=color_scheme,
#     199     plots=plots,
#     200     port=port,
#     201     address=address,
#     202     remote=remote,
#     203     browser=browser,
#     204     height=height,
#     205     auto=auto,
#     206     config=config,
#     207 )
#     209 if _session.remote:
#     210     logger.info(_REMOTE_INSTRUCTIONS.strip().format(_session.server_port))
#
# File c:\Users\chq-anyac\AppData\Local\Programs\Python\Python310\lib\site-packages\fiftyone\core\session\session.py:435, in Session.__init__(self, dataset, view, sample_id, group_id, spaces, color_scheme, plots, port, address, remote, browser, height, auto, config, view_name)
#     432 _register_session(self)
#     434 if self.auto and focx.is_notebook_context():
# --> 435     self.show(height=config.notebook_height)
#     437 self.browser = browser
#     439 if self.remote:
#
# File c:\Users\chq-anyac\AppData\Local\Programs\Python\Python310\lib\site-packages\fiftyone\core\session\session.py:251, in update_state.<locals>.decorator.<locals>.wrapper(session, *args, **kwargs)
#     249 if auto_show and session.auto and focx.is_notebook_context():
#     250     session.freeze()
# --> 251 result = func(session, *args, **kwargs)
#     252 session._client.send_event(StateUpdate(state=session._state))
#     253 if auto_show and session.auto and focx.is_notebook_context():
#
# File c:\Users\chq-anyac\AppData\Local\Programs\Python\Python310\lib\site-packages\fiftyone\core\session\session.py:1062, in Session.show(self, height)
#    1059 if not focx.is_notebook_context():
#    1060     return
# -> 1062 self.freeze()
#    1063 if self.dataset is not None:
#    1064     self.dataset._reload()
#
# File c:\Users\chq-anyac\AppData\Local\Programs\Python\Python310\lib\site-packages\fiftyone\core\session\session.py:1155, in Session.freeze(self)
#    1152     logger.warning("Only notebook sessions can be frozen")
#    1153     return
# -> 1155 self._client.send_event(DeactivateNotebookCell())
#    1156 self.plots.freeze()
#
# File c:\Users\chq-anyac\AppData\Local\Programs\Python\Python310\lib\site-packages\fiftyone\core\session\client.py:153, in Client.send_event(self, event)
#     150     return
#     152 if not self._connected:
# --> 153     raise RuntimeError("Client is not connected")
#     155 self._post_event(event)
#     156 self._dispatch_event(event)
#
# RuntimeError: Client is not connected

# %% [markdown]
# ## Summary
# Dimensionality reduction is critical to understanding our data, and our models. But it is important to think of dimensionality reduction not just as a single tool, but rather as a collection of techniques. Each technique has its own advantages; and each method projects certain assumptions onto the data, which may or may not hold for your data. I hope this walkthrough helps you to see your data in a new way!

# %%
mystop

# %% [markdown]
# ## Xtra

# %%
# #$xtra 51 Sample code - add samples with gt_label
# import fiftyone as fo

# dataset = fo.load_dataset("name")

# samples = []
# for filepath, label in zip(filepaths, labels):
#     sample = fo.Sample(filepath=filepath)
#     sample["ground_truth"] = fo.Classification(label=label)
#     samples.append(sample)

# dataset.add_samples(samples)

# %%
# $xtra 51 Sample code - add samples with gt_label and a field (one by one)
# dataset = fo.load_dataset("name")

# sample = fo.Sample(
#     filepath="DOC_IMAGES/DTW_2190599060_ANE_diGLmNgD3SlTBEw8wLOR8O0w2aCO53Spjdh_PAGE_0.jpg", 
#     ground_truth = fo.Classification(label="PackingList"))
# dataset.add_sample(sample)
# sample["carrier"] = "Carrier1"
# sample.save()


# sample2 = fo.Sample(
#     filepath="DOC_IMAGES/DTW_2190599388_BSH_WMDIcQgYdGnwXi2FCQOTj05G6LoKVy2xpaH_PAGE_0.jpg", 
#     ground_truth = fo.Classification(label="PurchaseOrder"))
# dataset.add_sample(sample2)
# sample2["carrier"] = "Carrier2"
# sample2.save()

# %%
#$xtra Snippet delete ds document-images
# refer to https://docs.voxel51.com/user_guide/using_datasets.html
# dataset_docs.delete()
# fo.list_datasets()

# %%
#$was: add samples with gt_label
#$fix need to set media type for the cell below to run, or produces an error
#$error: MediaTypeError: Unsupported media type 'None'
#$fix: refer to https://docs.voxel51.com/user_guide/using_datasets.html, looke for `media_type` property

#Reference
#task: Adding fields to a dataset  
# refer to https://docs.voxel51.com/user_guide/using_datasets.html#adding-fields-to-a-sample  
# https://docs.voxel51.com/user_guide/using_datasets.html#adding-fields-to-a-dataset

#dataset_docs.media_type #None

#add samples one by one
# sample = fo.Sample(filepath="DOC_IMAGES/DTW_2190599060_ANE_diGLmNgD3SlTBEw8wLOR8O0w2aCO53Spjdh_PAGE_0.jpg")
# dataset_docs.add_sample(sample)
# sample2 = fo.Sample(filepath="DOC_IMAGES/DTW_2190599388_BSH_WMDIcQgYdGnwXi2FCQOTj05G6LoKVy2xpaH_PAGE_0.jpg")
# dataset_docs.add_sample(sample2)

# #Load sample images and a gt_label
# if not DATASET_EXISTS:
#     i=0
#     for image in all_images:
#         #print(image)
#         dataset_docs.add_sample(fo.Sample(filepath=image, gt_label = fo.Classification(label=df_samples.iloc[i]['DOCUMENT_TYPE_NAME']))) #, tags=[df_samples.iloc[i]['DATA_SPLIT'], df_samples.iloc[i]['CARRIER']])))
#         i += 1

# #ensure right media type
# dataset_docs.media_type
